# %%
import pandas as pd

# %%
data = pd.read_csv('/workspaces/fitness-assistant-rag/data/yoga_poses_initial.csv')

data.head()
# Out:
#    id         pose_name type_of_practice props_required   body_focus  \
# 0   1         Low Lunge          Vinyasa          Block         Core
# 1   2         Crow Pose      Restorative        Bolster  Flexibility
# 2   3      Child's Pose          Vinyasa          Block      Balance
# 3   4        Camel Pose              Yin            NaN      Balance
# 4   5  Half Pigeon Pose      Restorative          Strap  Flexibility
#
#   pose_category          benefits  \
# 0     Inversion  Increases energy
# 1        Supine        Opens hips
# 2        Seated  Increases energy
# 3        Supine   Relieves stress
# 4        Supine  Increases energy
#
#                                         instructions
# 0  Lie flat on your back, arms at your sides, clo...
# 1  Kneel on the mat, sit back on heels, and stret...
# 2  Lie on back, bend knees, lift hips toward the ...
# 3  Stand on one leg, place foot on inner thigh, b...
# 4  Stand with feet wide apart, bend one knee and ...
